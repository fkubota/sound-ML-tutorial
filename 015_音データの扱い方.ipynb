# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

# %%
path = librosa.util.example_audio_file()
data, sr = librosa.load(path, sr=None)

# %%
plt.figure(figsize=(20, 5))
plt.plot(data)

# %% [markdown]
# 1. 横軸をsecにしてください。
# 2. 5 ~ 10 sec を切り出して可視化してください。(切り出したデータをdata2とする)
# 3. 任意の範囲start ~ end sec の音声を再生できるスニペットを作成してください。
